# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\uma\Downloads\Dataset .csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml? Gurme           208         ??stanbul
# 9547        5908749              Ceviz A??ac?           208         ??stanbul
# 9548        5915807                     Huqqa           208         ??stanbul
# 9549        5916112               A???k Kahve           208         ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ??stanbul
#
# ...

# %%
df.shape
# Out:
# (9551, 15)

# %%
the top three most
common cuisines in the dataset.

# %%
import pandas as pd


dataset = pd.read_csv(r"C:\Users\uma\Downloads\Dataset .csv")

# Check the first few rows to understand the structure
print(dataset.head())


if 'Cuisines' in dataset.columns:
    
    cuisine_counts = dataset['Cuisines'].dropna().str.split(', ').explode().value_counts()

   
    top_cuisines = cuisine_counts.head(3)

   
    print("Top 3 Most Common Cuisines:")
    print(top_cuisines)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
 # Calculate the percentage of restaurants serving each of the top cuisines

# %%
top_restaurant = len(df)
percentage =(top_cuisines/top_restaurant)*100
print(percentage)
# Out:
# Cuisines
# North Indian    31.326563
# Chinese          8.951942
# Fast Food        7.035912
# Name: count, dtype: float64

# %%
print('percentage of restaurants for top 3 Cuisines')
percentage
# Out:
# percentage of restaurants for top 3 Cuisines
# Cuisines
# North Indian    31.326563
# Chinese          8.951942
# Fast Food        7.035912
# Name: count, dtype: float64
